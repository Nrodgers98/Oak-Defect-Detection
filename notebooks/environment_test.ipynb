# %% [markdown]
# # Environment test
#
# ## 1. Verify data science/ML libraries
#
# Check that TensorFlow and PyTorch are importable and are the correct versions

# %%
import tensorflow as tf
import torch

print('TensorFlow version:', tf.__version__)
print('PyTorch version:', torch.__version__)
# Out:
# TensorFlow version: 2.16.1
# PyTorch version: 2.10.0+cu126

# %% [markdown]
# Check that GPU(s) are correctly detected and available for both frameworks

# %%
# TensorFlow GPU detection
print('TensorFlow GPUs:', tf.config.list_physical_devices('GPU'))

# PyTorch GPU selection (same pattern as training notebooks)
GPU_ID = 1  # choose 0 or 1

if torch.cuda.is_available():
    torch.cuda.set_device(GPU_ID)           # sets the current CUDA device
    DEVICE = torch.device(f"cuda:{GPU_ID}") # use this for .to(DEVICE)
    print(f"Using GPU {GPU_ID}: {torch.cuda.get_device_name(GPU_ID)}")
else:
    DEVICE = torch.device("cpu")
    print("Using CPU")

# PyTorch GPU detection
print(f'PyTorch CUDA available: {torch.cuda.is_available()}')
print(f'PyTorch CUDA device count: {torch.cuda.device_count()}')

if torch.cuda.is_available():
    for i in range(torch.cuda.device_count()):
        print(f'  GPU {i}: {torch.cuda.get_device_name(i)}')
# Out:
# TensorFlow GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]
# Using GPU 1: NVIDIA GeForce RTX 3090
# PyTorch CUDA available: True
# PyTorch CUDA device count: 2
#   GPU 0: NVIDIA GeForce RTX 4070 Ti
#   GPU 1: NVIDIA GeForce RTX 3090

# %% [markdown]
# Check other data science libraries:

# %%
import matplotlib as mpl
import numpy as np
import pandas as pd
import scipy as sp
import sklearn as sk

print('Matplotlib version:', mpl.__version__)
print('NumPy version:', np.__version__)
print('Pandas version:', pd.__version__)
print('Scikit-learn version:', sk.__version__)
print('SciPy version:', sp.__version__)
# Out:
# Matplotlib version: 3.10.8
# NumPy version: 1.26.4
# Pandas version: 2.2.1
# Scikit-learn version: 1.4.2
# SciPy version: 1.13.1

# %% [markdown]
# ## 2. GPU load test

# %%
# GPU load test - Matrix multiplication with memory scaling
from functions.gpu_load_test import run_gpu_load_test

target_memory_percent = 75.0
test_duration_seconds = 10 * 60

gpu_results = run_gpu_load_test(target_memory_percent, test_duration_seconds)
# Out:
# Memory growth enabled for 2 GPU(s)
# ============================================================
# Testing GPU 0: /physical_device:GPU:0
# ============================================================
# Total GPU memory: 16384 MB
# Initial memory used: 2084 MB (12.7%)
# Target: 75.0% memory usage
#
# Trying matrix size: 1000x1000... Memory: 2382 MB (14.5%)
# Trying matrix size: 2000x2000... Memory: 2478 MB (15.1%)
# Trying matrix size: 3000x3000... Memory: 2862 MB (17.5%)
# Trying matrix size: 4000x4000... Memory: 2862 MB (17.5%)
# Trying matrix size: 5000x5000... Memory: 3374 MB (20.6%)
# Trying matrix size: 6000x6000... Memory: 4398 MB (26.8%)
# Trying matrix size: 7000x7000... Memory: 4398 MB (26.8%)
# Trying matrix size: 8000x8000... Memory: 4398 MB (26.8%)
# Trying matrix size: 9000x9000... Memory: 6446 MB (39.3%)
# Trying matrix size: 10000x10000... Memory: 6446 MB (39.3%)
# Trying matrix size: 11000x11000... Memory: 6446 MB (39.3%)
# Trying matrix size: 12000x12000... Memory: 10542 MB (64.3%)
# Trying matrix size: 13000x13000... Memory: 10542 MB (64.3%)
# Trying matrix size: 14000x14000... Memory: 10542 MB (64.3%)
# Trying matrix size: 15000x15000... Memory: 10542 MB (64.3%)
# Trying matrix size: 16000x16000... Memory: 10542 MB (64.3%)
# Trying matrix size: 17000x17000... Memory: 15568 MB (95.0%)
#
# Reached 95.0% memory usage with 17000x17000 matrices
#
# Running stress test for 10 minutes at 17000x17000...
# Initial temperature: 31°C
#   32s elapsed, 568s remaining - Temp: 36°C, Iterations: 13
#   64s elapsed, 536s remaining - Temp: 39°C, Iterations: 26
#   97s elapsed, 503s remaining - Temp: 41°C, Iterations: 39
#   127s elapsed, 473s remaining - Temp: 43°C, Iterations: 51
#   158s elapsed, 442s remaining - Temp: 49°C, Iterations: 62
#   188s elapsed, 412s remaining - Temp: 48°C, Iterations: 74
#   221s elapsed, 379s remaining - Temp: 48°C, Iterations: 86
#   252s elapsed, 348s remaining - Temp: 49°C, Iterations: 98
#   283s elapsed, 317s remaining - Temp: 48°C, Iterations: 110
#   313s elapsed, 287s remaining - Temp: 48°C, Iterations: 122
#   343s elapsed, 257s remaining - Temp: 47°C, Iterations: 134
#   374s elapsed, 226s remaining - Temp: 51°C, Iterations: 146
#   405s elapsed, 195s remaining - Temp: 49°C, Iterations: 158
#   437s elapsed, 163s remaining - Temp: 48°C, Iterations: 171
#   469s elapsed, 131s remaining - Temp: 49°C, Iterations: 183
#   499s elapsed, 101s remaining - Temp: 48°C, Iterations: 195
#   531s elapsed, 69s remaining - Temp: 48°C, Iterations: 208
#   562s elapsed, 38s remaining - Temp: 49°C, Iterations: 220
#   592s elapsed, 8s remaining - Temp: 48°C, Iterations: 232
#
# GPU 0 stress test completed!
#   - Final matrix size: 17000x17000
#   - Peak memory usage: 15568 MB (95.0%)
#   - Total iterations: 236
#   - Total time: 602.4 seconds (10.0 minutes)
#   - Avg time per operation: 2.5527 seconds
#   - Temperature: 31°C → 48°C (Δ+17°C)
#
# ============================================================
# Testing GPU 1: /physical_device:GPU:1
# ============================================================
# Total GPU memory: 8192 MB
# Initial memory used: 1416 MB (17.3%)
# Target: 75.0% memory usage
#
# Trying matrix size: 1000x1000... Memory: 1489 MB (18.2%)
# Trying matrix size: 2000x2000... Memory: 1589 MB (19.4%)
# Trying matrix size: 3000x3000... Memory: 1973 MB (24.1%)
# Trying matrix size: 4000x4000... Memory: 1973 MB (24.1%)
# Trying matrix size: 5000x5000... Memory: 2485 MB (30.3%)
# Trying matrix size: 6000x6000... Memory: 3509 MB (42.8%)
# Trying matrix size: 7000x7000... Memory: 3509 MB (42.8%)
# Trying matrix size: 8000x8000... Memory: 3509 MB (42.8%)
# Trying matrix size: 9000x9000... Memory: 5557 MB (67.8%)
# Trying matrix size: 10000x10000... Memory: 5557 MB (67.8%)
# Trying matrix size: 11000x11000... Memory: 5532 MB (67.5%)
# Trying matrix size: 12000x12000... Memory: 7372 MB (90.0%)
#
# Reached 90.0% memory usage with 12000x12000 matrices
#
# Running stress test for 10 minutes at 12000x12000...
# Initial temperature: 59°C
#   31s elapsed, 569s remaining - Temp: 61°C, Iterations: 21
#   61s elapsed, 539s remaining - Temp: 62°C, Iterations: 41
#   92s elapsed, 508s remaining - Temp: 61°C, Iterations: 61
#   122s elapsed, 478s remaining - Temp: 61°C, Iterations: 81
#   152s elapsed, 448s remaining - Temp: 61°C, Iterations: 101
#   182s elapsed, 418s remaining - Temp: 62°C, Iterations: 121
#   212s elapsed, 388s remaining - Temp: 62°C, Iterations: 141
#   243s elapsed, 357s remaining - Temp: 62°C, Iterations: 161
#   274s elapsed, 326s remaining - Temp: 61°C, Iterations: 182
#   305s elapsed, 295s remaining - Temp: 61°C, Iterations: 203
#   336s elapsed, 264s remaining - Temp: 61°C, Iterations: 224
#   366s elapsed, 234s remaining - Temp: 61°C, Iterations: 244
#   397s elapsed, 203s remaining - Temp: 61°C, Iterations: 265
#   428s elapsed, 172s remaining - Temp: 61°C, Iterations: 286
#   459s elapsed, 141s remaining - Temp: 61°C, Iterations: 307
#   491s elapsed, 109s remaining - Temp: 61°C, Iterations: 328
#   521s elapsed, 79s remaining - Temp: 61°C, Iterations: 348
#   553s elapsed, 47s remaining - Temp: 61°C, Iterations: 369
#   584s elapsed, 16s remaining - Temp: 61°C, Iterations: 390
#
# GPU 1 stress test completed!
#   - Final matrix size: 12000x12000
#   - Peak memory usage: 7374 MB (90.0%)
#   - Total iterations: 402
#   - Total time: 601.0 seconds (10.0 minutes)
#   - Avg time per operation: 1.4951 seconds
#   - Temperature: 59°C → 61°C (Δ+2°C)
#
# ============================================================
# All 2 GPU(s) stress tested successfully!
# ============================================================

# %%
# Plot temperature over time for each GPU
from functions.gpu_load_test import plot_temperature_results

plot_temperature_results(gpu_results)

# %% [markdown]
# ## 3. PyTorch GPU load test

# %%
# PyTorch GPU load test - Matrix multiplication with memory scaling
from functions.pytorch_gpu_load_test import run_pytorch_gpu_load_test

target_memory_percent = 75.0
test_duration_seconds = 10 * 60

pytorch_gpu_results = run_pytorch_gpu_load_test(target_memory_percent, test_duration_seconds)
# Out:
# Found 2 CUDA GPU(s)
#   GPU 0: NVIDIA GeForce RTX 4070 Ti
#   GPU 1: NVIDIA GeForce RTX 3090
# ============================================================
# Testing GPU 0: NVIDIA GeForce RTX 4070 Ti
# ============================================================
# Total GPU memory: 12282 MB
# Initial memory used: 3492 MB (28.4%)
# Target: 75.0% memory usage
#
# Trying matrix size: 1000x1000... Memory: 3709 MB (30.2%)
# Trying matrix size: 2000x2000... Memory: 3757 MB (30.6%)
# Trying matrix size: 3000x3000... Memory: 3865 MB (31.5%)
# Trying matrix size: 4000x4000... Memory: 4004 MB (32.6%)
# Trying matrix size: 5000x5000... Memory: 4184 MB (34.1%)
# Trying matrix size: 6000x6000... Memory: 4412 MB (35.9%)
# Trying matrix size: 7000x7000... Memory: 4688 MB (38.2%)
# Trying matrix size: 8000x8000... Memory: 5012 MB (40.8%)
# Trying matrix size: 9000x9000... Memory: 5378 MB (43.8%)
# Trying matrix size: 10000x10000... Memory: 5786 MB (47.1%)
# Trying matrix size: 11000x11000... Memory: 6242 MB (50.8%)
# Trying matrix size: 12000x12000... Memory: 6746 MB (54.9%)
# Trying matrix size: 13000x13000... Memory: 7298 MB (59.4%)
# Trying matrix size: 14000x14000... Memory: 7892 MB (64.3%)
# Trying matrix size: 15000x15000... Memory: 8534 MB (69.5%)
# Trying matrix size: 16000x16000... Memory: 9210 MB (75.0%)
# Trying matrix size: 17000x17000... Memory: 9931 MB (80.9%)
#
# Reached 80.9% memory usage with 17000x17000 matrices
#
# Running stress test for 10 minutes at 17000x17000...
# Initial temperature: 78°C
#   30s elapsed, 570s remaining - Temp: 77°C, Iterations: 79
#   60s elapsed, 540s remaining - Temp: 78°C, Iterations: 152
#   91s elapsed, 509s remaining - Temp: 79°C, Iterations: 224
#   121s elapsed, 479s remaining - Temp: 78°C, Iterations: 296
#   151s elapsed, 449s remaining - Temp: 80°C, Iterations: 369
#   181s elapsed, 419s remaining - Temp: 77°C, Iterations: 442
#   211s elapsed, 389s remaining - Temp: 79°C, Iterations: 513
#   241s elapsed, 359s remaining - Temp: 80°C, Iterations: 589
#   271s elapsed, 329s remaining - Temp: 80°C, Iterations: 665
#   302s elapsed, 298s remaining - Temp: 78°C, Iterations: 742
#   332s elapsed, 268s remaining - Temp: 79°C, Iterations: 818
#   362s elapsed, 238s remaining - Temp: 81°C, Iterations: 895
#   392s elapsed, 208s remaining - Temp: 80°C, Iterations: 971
#   422s elapsed, 178s remaining - Temp: 78°C, Iterations: 1048
#   453s elapsed, 147s remaining - Temp: 78°C, Iterations: 1125
#   483s elapsed, 117s remaining - Temp: 80°C, Iterations: 1206
#   513s elapsed, 87s remaining - Temp: 80°C, Iterations: 1283
#   543s elapsed, 57s remaining - Temp: 80°C, Iterations: 1360
#   574s elapsed, 26s remaining - Temp: 80°C, Iterations: 1437
#
# GPU 0 stress test completed!
#   - Final matrix size: 17000x17000
#   - Peak memory usage: 11029 MB (89.8%)
#   - Total iterations: 1505
#   - Total time: 600.2 seconds (10.0 minutes)
#   - Avg time per operation: 0.3988 seconds
#   - Temperature: 78°C → 79°C (Δ+1°C)
#
# ============================================================
# Testing GPU 1: NVIDIA GeForce RTX 3090
# ============================================================
# Total GPU memory: 24576 MB
# Initial memory used: 516 MB (2.1%)
# Target: 75.0% memory usage
#
# Trying matrix size: 1000x1000... Memory: 548 MB (2.2%)
# Trying matrix size: 2000x2000... Memory: 596 MB (2.4%)
# Trying matrix size: 3000x3000... Memory: 704 MB (2.9%)
# Trying matrix size: 4000x4000... Memory: 842 MB (3.4%)
# Trying matrix size: 5000x5000... Memory: 1022 MB (4.2%)
# Trying matrix size: 6000x6000... Memory: 1250 MB (5.1%)
# Trying matrix size: 7000x7000... Memory: 1526 MB (6.2%)
# Trying matrix size: 8000x8000... Memory: 1850 MB (7.5%)
# Trying matrix size: 9000x9000... Memory: 2216 MB (9.0%)
# Trying matrix size: 10000x10000... Memory: 2624 MB (10.7%)
# Trying matrix size: 11000x11000... Memory: 3080 MB (12.5%)
# Trying matrix size: 12000x12000... Memory: 3584 MB (14.6%)
# Trying matrix size: 13000x13000... Memory: 4136 MB (16.8%)
# Trying matrix size: 14000x14000... Memory: 4730 MB (19.2%)
# Trying matrix size: 15000x15000... Memory: 5372 MB (21.9%)
# Trying matrix size: 16000x16000... Memory: 6062 MB (24.7%)
# Trying matrix size: 17000x17000... Memory: 6794 MB (27.6%)
# Trying matrix size: 18000x18000... Memory: 7568 MB (30.8%)
# Trying matrix size: 19000x19000... Memory: 8390 MB (34.1%)
# Trying matrix size: 20000x20000... Memory: 9260 MB (37.7%)
# Trying matrix size: 21000x21000... Memory: 10178 MB (41.4%)
# Trying matrix size: 22000x22000... Memory: 11144 MB (45.3%)
# Trying matrix size: 23000x23000... Memory: 12146 MB (49.4%)
# Trying matrix size: 24000x24000... Memory: 13196 MB (53.7%)
# Trying matrix size: 25000x25000... Memory: 14300 MB (58.2%)
# Trying matrix size: 26000x26000... Memory: 15446 MB (62.8%)
# Trying matrix size: 27000x27000... Memory: 16634 MB (67.7%)
# Trying matrix size: 28000x28000... Memory: 17870 MB (72.7%)
# Trying matrix size: 29000x29000... Memory: 19154 MB (77.9%)
#
# Reached 77.9% memory usage with 29000x29000 matrices
#
# Running stress test for 10 minutes at 29000x29000...
# Initial temperature: 42°C
#   31s elapsed, 569s remaining - Temp: 49°C, Iterations: 15
#   63s elapsed, 537s remaining - Temp: 55°C, Iterations: 30
#   95s elapsed, 505s remaining - Temp: 59°C, Iterations: 45
#   125s elapsed, 475s remaining - Temp: 62°C, Iterations: 59
#   155s elapsed, 445s remaining - Temp: 62°C, Iterations: 73
#   187s elapsed, 413s remaining - Temp: 61°C, Iterations: 88
#   218s elapsed, 382s remaining - Temp: 60°C, Iterations: 102
#   248s elapsed, 352s remaining - Temp: 60°C, Iterations: 116
#   278s elapsed, 322s remaining - Temp: 60°C, Iterations: 130
#   308s elapsed, 292s remaining - Temp: 60°C, Iterations: 144
#   339s elapsed, 261s remaining - Temp: 60°C, Iterations: 158
#   370s elapsed, 230s remaining - Temp: 60°C, Iterations: 173
#   400s elapsed, 200s remaining - Temp: 60°C, Iterations: 187
#   430s elapsed, 170s remaining - Temp: 61°C, Iterations: 201
#   461s elapsed, 139s remaining - Temp: 61°C, Iterations: 215
#   492s elapsed, 108s remaining - Temp: 61°C, Iterations: 229
#   524s elapsed, 76s remaining - Temp: 60°C, Iterations: 244
#   554s elapsed, 46s remaining - Temp: 60°C, Iterations: 258
#   584s elapsed, 16s remaining - Temp: 61°C, Iterations: 272
#
# GPU 1 stress test completed!
#   - Final matrix size: 29000x29000
#   - Peak memory usage: 22364 MB (91.0%)
#   - Total iterations: 280
#   - Total time: 601.1 seconds (10.0 minutes)
#   - Avg time per operation: 2.1467 seconds
#   - Temperature: 42°C → 60°C (Δ+18°C)
#
# ============================================================
# All 2 GPU(s) stress tested successfully with PyTorch!
# ============================================================

# %%
# Plot temperature over time for each GPU
from functions.pytorch_gpu_load_test import plot_temperature_results

plot_temperature_results(pytorch_gpu_results)
